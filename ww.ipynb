# %%
import pandas as pd

# %%
df11=pd.read_excel("C:\\Users\\ASUS\\Downloads\\dataset.xlsx")

# %%
df11.columns = [c[0] + "_" + c[1] for c in df11.]
new_header = df11.iloc[0] #grab the first row for the header
df11 = df11[2:] #take the data less the header row
df11.columns = new_header #set the
df11.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2264/3740504577.py in <module>
# ----> 1 df11.columns = [c[0] + "_" + c[1] for c in df11.rows]
#       2 new_header = df11.iloc[0] #grab the first row for the header
#       3 df11 = df11[2:] #take the data less the header row
#       4 df11.columns = new_header #set the
#       5 df11.head(20)
#
# c:\users\asus\pycharmprojects\quarterly_median_rents-analysis-\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df=pd.ExcelFile("C:\\Users\\ASUS\\Downloads\\dataset.xlsx")

# %%
df.sheet_names
# Out:
# ['1br flat',
#  '2br Flat',
#  '3br Flat',
#  '2br House',
#  '3br House',
#  '4br House',
#  'All Properties']

# %%
df

# %%
sheets = df.sheet_names

df1 = pd.concat([pd.read_excel(workbook, sheet_name=s)
                .assign(sheet_name=s) for s in sheets])

# %%
workbook = pd.ExcelFile("C:\\Users\\ASUS\\Downloads\\dataset.xlsx")
sheets = workbook.sheet_names

df = pd.concat([pd.read_excel(workbook, sheet_name=s)
                .assign(sheet_name=s) for s in sheets])
# df.drop(df.index[[0]],inplace=True)

# %%
df.head(100)
# Out:
#        1 bedroom flat       Unnamed: 1 Lease commenced in quarter Unnamed: 3  \
# 0                 NaN              NaN                   Jun 1999        NaN
# 1              Region              LGA                      Count     Median
# 2   Barwon South West      Colac-Otway                          6         68
# 3                 NaN      Corangamite                          -          -
# 4                 NaN          Glenelg                          7         65
# ..                ...              ...                        ...        ...
# 1                 NaN              LGA                      Count     Median
# 2                 NaN      Colac-Otway                         18        110
# 3                 NaN      Corangamite                          -          -
# 4                 NaN          Glenelg                         20        100
# 5                 NaN  Greater Geelong                        387        125
#
# ...

# %%
df1=df.stack()

# %%
df1.tail(20)
# Out:
# 93  Unnamed: 162             48725
#     Unnamed: 163               400
#     Unnamed: 164             55160
#     Unnamed: 165               400
#     Unnamed: 166             51631
#     Unnamed: 167               400
#     Unnamed: 168             62720
#     Unnamed: 169               410
#     Unnamed: 170             47088
#     Unnamed: 171               390
#     Unnamed: 172             48411
#     Unnamed: 173               390
#     Unnamed: 174             55017
#     Unnamed: 175               390
#     Unnamed: 176             65229
#     Unnamed: 177               390
#     Unnamed: 178             53258
#     Unnamed: 179               385
#     sheet_name      All Properties
#     Unnamed: 2               31033
# dtype: object

# %%
df.tail(20)
# Out:
#    1 bedroom flat          Unnamed: 1 Lease commenced in quarter Unnamed: 3  \
# 74            NaN              Monash                        NaN        190
# 75            NaN          Whitehorse                        NaN        185
# 76            NaN        Yarra Ranges                        NaN        150
# 77            NaN         Group Total                        NaN        185
# 78            NaN             Bayside                        NaN        250
# 79            NaN            Cardinia                        NaN        155
# 80            NaN               Casey                        NaN        160
# 81            NaN           Frankston                        NaN        150
# 82            NaN           Glen Eira                        NaN        180
# 83            NaN   Greater Dandenong                        NaN        138
# 84            NaN            Kingston                        NaN        165
# ...

# %%
df_dict = pd.read_excel("C:\\Users\\ASUS\\Downloads\\dataset.xlsx", header=[0, 1,2], sheet_name=None)

# %%
df = pd.concat(df_dict.values(), axis=0)

# %%
df.head(20)
# Out:
#        1 bedroom flat                         2 bedroom flat  \
#    Unnamed: 0_level_1  Unnamed: 1_level_1 Unnamed: 0_level_1
#                Region                 LGA             Region
# 0   Barwon South West         Colac-Otway                NaN
# 1                 NaN         Corangamite                NaN
# 2                 NaN             Glenelg                NaN
# 3                 NaN     Greater Geelong                NaN
# 4                 NaN               Moyne                NaN
# 5                 NaN        Queenscliffe                NaN
# 6                 NaN  Southern Grampians                NaN
# 7                 NaN          Surf Coast                NaN
# 8                 NaN         Warrnambool                NaN
# 9                 NaN         Group Total                NaN
# 10          Grampians              Ararat                NaN
# 11                NaN            Ballarat                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 0 to 91
# Columns: 370 entries, ('1 bedroom flat', 'Unnamed: 0_level_1', 'Region') to ('Lease commenced in quarter', 'Sep 2020', 'Median')
# dtypes: float64(126), object(244)
# memory usage: 1.8+ MB

# %%
df.tail(20)
# Out:
#        1 bedroom flat                        2 bedroom flat  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 0_level_1
#                Region                LGA             Region
# 72                NaN                NaN                NaN
# 73                NaN                NaN                NaN
# 74                NaN                NaN                NaN
# 75                NaN                NaN                NaN
# 76                NaN                NaN                NaN
# 77                NaN                NaN                NaN
# 78                NaN                NaN                NaN
# 79                NaN                NaN                NaN
# 80                NaN                NaN                NaN
# 81                NaN                NaN                NaN
# 82                NaN                NaN                NaN
# 83                NaN                NaN                NaN
# 84                NaN                NaN                NaN
# ...

# %%
workbook = pd.ExcelFile("C:\\Users\\ASUS\\Downloads\\dataset.xlsx")
sheets = workbook.sheet_names

df = pd.concat([pd.read_excel(workbook, sheet_name=s)
                .assign(sheet_name=s) for s in sheets])
# df.drop(df.index[[0]],inplace=True)

# %%
df.columns = [c[0] + "_" + c[1] for c in df.columns]
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the
df.head(20)
# Out:
# 0                 NaN                 NaN Jun 1999     NaN Sep 1999     NaN  \
# 1              Region                 LGA    Count  Median    Count  Median
# 2   Barwon South West         Colac-Otway        6      68        6      75
# 3                 NaN         Corangamite        -       -        5      60
# 4                 NaN             Glenelg        7      65        -       -
# 5                 NaN     Greater Geelong      202      80      205      80
# 6                 NaN               Moyne        -       -        -       -
# 7                 NaN        Queenscliffe        -       -        -       -
# 8                 NaN  Southern Grampians        9      65       10      68
# 9                 NaN          Surf Coast        9     100        9      92
# 10                NaN         Warrnambool       28      75       22      75
# 11                NaN         Group Total      264      80      261      80
# ...
